# %% [markdown]
# # Install System Dependencies

# %%
# !apt-get update -qq
# !apt-get install -y -qq \
    libsndfile1 \
    ffmpeg \
    libavcodec-extra \
    build-essential \
    cmake \
    swig
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Selecting previously unselected package libaribb24-0:amd64.
# (Reading database ... 121852 files and directories currently installed.)
# Preparing to unpack .../libaribb24-0_1.0.3-2_amd64.deb ...
# Unpacking libaribb24-0:amd64 (1.0.3-2) ...
# Selecting previously unselected package libopencore-amrnb0:amd64.
# Preparing to unpack .../libopencore-amrnb0_0.1.5-1_amd64.deb ...
# Unpacking libopencore-amrnb0:amd64 (0.1.5-1) ...
# Selecting previously unselected package libopencore-amrwb0:amd64.
# Preparing to unpack .../libopencore-amrwb0_0.1.5-1_amd64.deb ...
# Unpacking libopencore-amrwb0:amd64 (0.1.5-1) ...
# Selecting previously unselected package libvo-amrwbenc0:amd64.
# Preparing to unpack .../libvo-amrwbenc0_0.1.3-2_amd64.deb ...
# Unpacking libvo-amrwbenc0:amd64 (0.1.3-2) ...
# dpkg: libavcodec58:amd64: dependency problems, but removing anyway as you requested:
#  libchromaprint1:amd64 depends on libavcodec58 (>= 7:4.4).
#  libavformat58:amd64 depends on libavcodec58 (= 7:4.4.2-0ubuntu0.22.04.1).
#  libavfilter7:amd64 depends on libavcodec58 (= 7:4.4.2-0ubuntu0.22.04.1).
#  libavdevice58:amd64 depends on libavcodec58 (= 7:4.4.2-0ubuntu0.22.04.1).
#  ffmpeg depends on libavcodec58 (= 7:4.4.2-0ubuntu0.22.04.1).
#
# (Reading database ... 121876 files and directories currently installed.)
# Removing libavcodec58:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Selecting previously unselected package libavcodec-extra58:amd64.
# (Reading database ... 121870 files and directories currently installed.)
# Preparing to unpack .../libavcodec-extra58_7%3a4.4.2-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libavcodec-extra58:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Selecting previously unselected package swig4.0.
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Selecting previously unselected package libavcodec-extra:amd64.
# Preparing to unpack .../libavcodec-extra_7%3a4.4.2-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libavcodec-extra:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libvo-amrwbenc0:amd64 (0.1.3-2) ...
# Setting up libaribb24-0:amd64 (1.0.3-2) ...
# Setting up libopencore-amrwb0:amd64 (0.1.5-1) ...
# Setting up libopencore-amrnb0:amd64 (0.1.5-1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Setting up libavcodec-extra58:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libavcodec-extra:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link

# %% [markdown]
# # Clone/Mount NatureLM Repo

# %%
# !git clone https://github.com/earthspecies/NatureLM-audio.github

from google.colab import drive
drive.mount('/content/drive')

import os
naturelm_drive_path = "/content/drive/MyDrive/NatureLMaudio"
data_drive_path = "/content/drive/MyDrive/AnuraSet"

# Create symlinks in the current working directory
if not os.path.exists("NatureLMaudio"):
    # !ln -s "{naturelm_drive_path}" NatureLMaudio

if not os.path.exists("data"):
    os.makedirs("data", exist_ok=True)
    # !ln -s "{data_drive_path}" data/AnuraSet

# %cd NatureLMaudio
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/NatureLMaudio

# %% [markdown]
# # Upgrade pip and install NatureLM CPU or GPU version

# %%
# Step 1: System dependencies
print("\n[1/8] Installing system dependencies...")
# !apt-get update -qq
# !apt-get install -y -qq \
    python3-tk \
    libopenblas-dev \
    libomp-dev \
    curl \
    git \
    cmake \
    build-essential \
    swig \
    libsndfile1 \
    ffmpeg \
    libavcodec-extra

# Step 2: Upgrade pip
print("\n[2/8] Upgrading pip...")
# !pip install --upgrade pip

# Step 3: Install Python dependencies with EXACT versions from your environment
print("\n[3/8] Installing Python dependencies with pinned versions...")

# Core dependencies
# !pip install numpy==1.26.4

# Audio processing
# !pip install librosa==0.9.2
# !pip install soundfile==0.12.1
# !pip install audioread==3.0.1
# !pip install resampy==0.3.1
# !pip install pydub==0.25.1

# ML/DL frameworks
# !pip install transformers==4.44.2
# !pip install accelerate==0.31.0
# !pip install peft==0.11.1
# !pip install datasets==3.5.0
# !pip install einops==0.8.0
# !pip install safetensors==0.4.3

# Scientific computing
# !pip install scipy==1.14.0
# !pip install pandas==1.4.3
# !pip install scikit-learn==1.1.1
# !pip install matplotlib==3.9.0
# !pip install bitsandbytes

# Web/API (optional for Colab)
# !pip install fastapi==0.115.11
# !pip install uvicorn==0.30.1
# !pip install gradio==5.20.0
# !pip install aiohttp==3.11.11

# Utilities
# !pip install tqdm==4.66.4
# !pip install pillow==10.3.0
# !pip install huggingface-hub==0.29.1
# !pip install pyyaml==6.0
# !pip install rich==14.0.0
# !pip install pydantic==2.7.4
# !pip install python-dotenv==1.0.1
# !pip install numba==0.60.0
# !pip install llvmlite==0.43.0
# !pip install uv
# !pip install openpyxl
# !pip install pydantic-settings
# !pip install cloudpathlib
# !pip install google-cloud-storage
# !pip install wandb
# !pip install tensorboard
# !pip install seaborn

# Audio evaluation
# !pip install mir-eval==0.7

# Step 4: Install beans-zero
print("\n[4/8] Installing beans-zero...")
# !pip install git+https://github.com/earthspecies/beans-zero.git@31d4487ee6452ae6c31853d45fd38b7d4150372d

# Step 5: Install NatureLM-audio
print("\n[5/8] Installing NatureLM-audio...")

# Navigate to NatureLMaudio directory
import os
from pathlib import Path

# Try to find NatureLMaudio
possible_paths = [
    "/content/drive/MyDrive/NatureLMaudio",
    str(Path.cwd() / "NatureLMaudio")
]

naturelm_path = None
for path in possible_paths:
    if os.path.exists(path):
        naturelm_path = path
        print(f"Found NatureLMaudio at: {naturelm_path}")
        break

if naturelm_path:
    original_dir = os.getcwd()
    os.chdir(naturelm_path)
    # !pip install -e .[gpu] --no-deps
    os.chdir(original_dir)
    print("NatureLM-audio installed")
else:
    print("Could not find NatureLMaudio directory")
    print("Please ensure it exists in one of these locations:")
    for path in possible_paths:
        print(f"  - {path}")

# Step 7: Clean pip cache
# !pip cache purge

# Navigate to the NatureLM-audio directory and install from there
import os

# Check where you are and where NatureLM-audio is
print("Current directory:", os.getcwd())
print("NatureLMaudio exists:", os.path.exists("NatureLMaudio"))

# Change to the NatureLMaudio directory and install
if os.path.exists("NatureLMaudio"):
  # %cd NatureLMaudio
  # Uncomment the install you want
  # !pip install -e . # For CPU install
  # !pip install -e .[gpu] --no-deps # For GPU install
  # %cd ..
else:
  print("NatureLMaudio directory not found in current path")
  
  # Try the full path
  naturelm_path = "/content/drive/MyDrive/NatureLMaudio"
  if os.path.exists(naturelm_path):
    # %cd "{naturelm_path}"
      
    # Uncomment the install you want
    # !pip install -e . # For CPU install
    # !pip install -e .[gpu] --no-deps # For GPU install
    # %cd /content
  else:
      print(f"NatureLMaudio not found at {naturelm_path}")
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-26.0.1-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-26.0.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 42.6 MB/s eta 0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-26.0.1
# Obtaining file:///content/drive/MyDrive/NatureLMaudio
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
# INFO: pip is looking at multiple versions of naturelm-audio to determine which version is compatible with other requirements. This could take a while.
# ERROR: Could not find a version that satisfies the requirement beans-zero (from naturelm-audio) (from versions: none)
# ERROR: No matching distribution found for beans-zero

# %% [markdown]
# # Install BEANS-Zero

# %%
# %cd ..

# Install beans-zero with dependency resolution ignoring conflicts
# !pip install --no-deps git+https://github.com/earthspecies/beans-zero.git@31d4487ee6452ae6c31853d45fd38b7d4150372d
# Out:
# /content/drive/MyDrive
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for beans-zero (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.37.0 requires rich<14,>=12.4.4, but you have rich 14.3.3 which is incompatible.

# %% [markdown]
# # Install bitsandbytes

# %%
# !pip install "rich<14"
# !pip install bitsandbytes
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: torch<3,>=2.3 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (2.10.0+cu128)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (2.0.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (26.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.25.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch<3,>=2.3->bitsandbytes) (1.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3,>=2.3->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3,>=2.3->bitsandbytes) (3.0.3)
# Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl (60.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 81.2 MB/s  0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.49.2

# %% [markdown]
# # Verification of some installs

# %%
import torch

print("Torch version:", torch.__version__)
if torch.cuda.is_available():
    print("CUDA available:", torch.cuda.is_available())
    print("GPU:", torch.cuda.get_device_name(0))

import bitsandbytes as bnb
print("bitsandbytes version:", bnb.__version__)
# Out:
# Torch version: 2.10.0+cu128
# CUDA available: True
# GPU: NVIDIA L4
# bitsandbytes version: 0.49.2

# %% [markdown]
# # Download Our Code

# %%
if os.path.exists("CS491-691-Adaptation-of-NatureLM-to-Unseen-Domains"):
  import shutil
  shutil.rmtree("CS491-691-Adaptation-of-NatureLM-to-Unseen-Domains")
# !git clone https://github.com/CarterAWebb827/CS491-691-Adaptation-of-NatureLM-to-Unseen-Domains.git
# Out:
# fatal: destination path 'CS491-691-Adaptation-of-NatureLM-to-Unseen-Domains' already exists and is not an empty directory.
# Current working directory: /content/drive/MyDrive
# Files here: ['Colab Notebooks', 'Game Assets', 'CS631 Cheat Sheet.gdoc', "Master's Classes.gdoc", 'CS 691 Midterm 2 Study Guide.gdoc', 'Project Final Report.gdoc', 'Travel Itinerary.gdoc', 'Midterm_CS642.gdoc', 'VLM Project Proposal.gslides', 'Mammo-CLIP_Carter Webb.gslides', 'GLAM_Carter-Webb.gslides', 'Interim_Report.gslides', 'CLAHE.gslides', 'Mammo-SAE_Carter-Webb.gslides', 'Final Exam - Main Project.gdoc', 'Final Project Presentation.gslides', 'Benchmarking Retrieval-Augmented Generation for Medicine.gslides', 'MIRAGE: A Metric-Intensive Benchmark for Retrieval-Augmented Generation Evaluation.gslides', '01 23 25 Meeting.gslides', 'CS 793Q 01 30 25 Meeting.gslides', 'Webb_Carter_HW1.docx', 'Research Docs.gdoc', 'CS 793Q 02 06 25 Meeting.gslides', 'NatureLM-audio: An Audio-Language Foundation Model for Bioacoustics.gslides', 'AI PP.docx', 'CS 491 691 - Project Proposal Full.gdoc', 'CS 793Q 02 13 25 Meeting.gslides', 'Reasearch Meeting - 02 17 26.gslides', 'CS 793Q 02 21 25 Meeting.gslides', 'Untitled presentation.gslides', 'Carter Webb CS 691 Project Proposal.gdoc', 'Reasearch Meeting - 02 24 26.gslides', 'Homework 2 CS 691 - Carter Webb.gdoc', 'NatureLM-audio In-Depth.gdoc', 'Research Meeting - 03 03 26.gslides', 'PNW-Cnet-v5.gdoc', 'Simulated Soundscapes and Transfer Learning.gdoc', 'Multi-Modal Language Models in Bioacoustics with Zero-Shot Transfer.gdoc', 'Lab.gslides', 'AnuraSet', 'A Multi-Time-Frequency Feature Fusion Approach for Marine Mammal Sound Recognition.gdoc', 'Project_Pitch_491_691.gslides', 'CS491 691 Project Pitch.gslides', 'NatureLMaudio', 'CS491-691-Adaptation-of-NatureLM-to-Unseen-Domains', 'data']
# ✗ fine_tune.py NOT found
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4396/3392786345.py in <cell line: 0>()
#      14     print("✗ fine_tune.py NOT found")
#      15     # Search for it
# ---> 16     get_ipython().system('find . -name "fine_tune.py" 2>/dev/null')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      94       kwargs.update({'also_return_output': True})
#      95
# ---> 96     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#      97
#      98     if pip_warn:
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     452   # is expected to call this function, thus adding one level of nesting to the
#     453   # stack.
# --> 454   result = _run_command(
#     455       shell.var_expand(cmd, depth=2), clear_streamed_output=False
#     456   )
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_system_commands.py in _run_command(cmd, clear_streamed_output)
#     202       os.close(child_pty)
#     203
# --> 204       return _monitor_process(parent_pty, epoll, p, cmd, update_stdin_widget)
#     205   finally:
#     206     epoll.close()
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_system_commands.py in _monitor_process(parent_pty, epoll, p, cmd, update_stdin_widget)
#     232   while True:
#     233     try:
# --> 234       result = _poll_process(parent_pty, epoll, p, cmd, decoder, state)
#     235       if result is not None:
#     236         return result
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_system_commands.py in _poll_process(parent_pty, epoll, p, cmd, decoder, state)
#     280   output_available = False
#     281
# --> 282   events = epoll.poll()
#     283   input_events = []
#     284   for _, event in events:
#
# KeyboardInterrupt:

# %% [markdown]
# # Edit the YAML

# %%
import yaml

# Path to your YAML file
yaml_path = f"{naturelm_drive_path}/configs/finetune_anura.yaml"

# Load the YAML
with open(yaml_path, 'r') as f:
    config = yaml.safe_load(f)

# Update paths to use mounted locations
config["model"]["beats_path"] = f"{naturelm_drive_path}/models/beats/BEATs_iter3_plus_AS2M_finetuned_on_AS2M_cpt2.pt"
config["datasets"]["train_ann_path"] = f"{naturelm_drive_path}/NatureLM/dummy.jsonl"
config["datasets"]["valid_ann_path"] = f"{naturelm_drive_path}/NatureLM/dummy.jsonl"
config["datasets"]["test_ann_path"] = f"{naturelm_drive_path}/NatureLM/dummy.jsonl"

# %% [markdown]
# # Run Program

# %%
# !python CS491-691-Adaptation-of-NatureLM-to-Unseen-Domains/fine_tune.py --data_dir "{data_drive_path}"
# Out:
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/CS491-691-Adaptation-of-NatureLM-to-Unseen-Domains/fine_tune.py", line 4, in <module>
#     from huggingface_hub import HfFolder, login
# ImportError: cannot import name 'HfFolder' from 'huggingface_hub' (/usr/local/lib/python3.12/dist-packages/huggingface_hub/__init__.py)
