# %% [markdown]
# # Install System Dependencies

# %%
# !apt-get update -qq
# !apt-get install -y -qq \
    libsndfile1 \
    ffmpeg \
    libavcodec-extra \
    build-essential \
    cmake \
    swig

# %% [markdown]
# # Install PyTorch

# %%
# !pip install -q torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# %% [markdown]
# # Install Dependencies need for NatureLM-audio and BEANS-Zero

# %%
# !pip install -q \
    numpy==1.26.4 \
    librosa==0.9.2 \
    soundfile==0.12.1 \
    audioread==3.0.1 \
    resampy==0.3.1 \
    pydub==0.25.1 \
    transformers==4.44.2 \
    accelerate==0.31.0 \
    peft==0.11.1 \
    datasets==3.5.0 \
    einops==0.8.0 \
    safetensors==0.4.3 \
    scipy==1.14.0 \
    pandas==1.4.3 \
    scikit-learn==1.1.1 \
    matplotlib==3.9.0 \
    fastapi==0.115.11 \
    uvicorn==0.30.1 \
    gradio==5.20.0 \
    aiohttp==3.11.11 \
    tqdm==4.66.4 \
    pillow==10.3.0 \
    huggingface-hub==0.29.1 \
    pyyaml==6.0 \
    rich==14.0.0 \
    pydantic==2.7.4 \
    python-dotenv==1.0.1 \
    mir-eval==0.7 \
    numba==0.60.0 \
    llvmlite==0.43.0 \
    openpyxl \
    pydantic-settings \
    cloudpathlib \
    google-cloud-storage \
    wandb \
    tensorboard \
    bitsandbytes

# %% [markdown]
# # Install BEANS-Zero

# %%
# !pip install -q git+https://github.com/earthspecies/beans-zero.git@31d4487ee6452ae6c31853d45fd38b7d4150372d
