# %% [markdown]
# # Install System Dependencies

# %%
# !pip install --upgrade --force-reinstall numpy==1.26.4 pandas==2.2.2
# Out:
# ...
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# ...
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 140.6 MB/s  0:00:00
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# ...
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# ...
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.2
#     Uninstalling pytz-2025.2:
#       Successfully uninstalled pytz-2025.2━━━━━━ 0/6 [pytz]
#   Attempting uninstall: tzdata━━━━━━━━━━━━━━━━━━ 0/6 [pytz]
#     Found existing installation: tzdata 2025.30m 0/6 [pytz]
#     Uninstalling tzdata-2025.3:0m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/6 [tzdata]
# ...

# %%
# !apt-get update -qq
# !apt-get install -y -qq \
    libsndfile1 \
    ffmpeg \
    libavcodec-extra \
    build-essential \
    cmake \
    swig
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %% [markdown]
# # Clone/Mount NatureLM Repo

# %%
# !git clone https://github.com/earthspecies/NatureLM-audio.github

from google.colab import drive
drive.mount('/content/drive')

import os
naturelm_drive_path = "/content/drive/MyDrive/NatureLMaudio"
data_drive_path = "/content/drive/MyDrive/AnuraSet"

# Create symlinks in the current working directory
if not os.path.exists("NatureLMaudio"):
    # !ln -s "{naturelm_drive_path}" NatureLMaudio

if not os.path.exists("data"):
    os.makedirs("data", exist_ok=True)
    # !ln -s "{data_drive_path}" data/AnuraSet

# %cd NatureLMaudio
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/NatureLMaudio

# %% [markdown]
# # Upgrade pip and install NatureLM CPU or GPU version

# %%
# Step 1: System dependencies
print("\n[1/8] Installing system dependencies...")
# !apt-get update -qq
# !apt-get install -y -qq \
    python3-tk \
    libopenblas-dev \
    libomp-dev \
    curl \
    git \
    cmake \
    build-essential \
    swig \
    libsndfile1 \
    ffmpeg \
    libavcodec-extra

# Step 2: Upgrade pip
print("\n[2/8] Upgrading pip...")
# !pip install --upgrade pip

# Step 3: Install Python dependencies with EXACT versions from your environment
print("\n[3/8] Installing Python dependencies with pinned versions...")

# Core dependencies
# !pip install numpy==1.26.4

# Audio processing
# !pip install librosa==0.9.2
# !pip install soundfile==0.12.1
# !pip install audioread==3.0.1
# !pip install resampy==0.3.1
# !pip install pydub==0.25.1

# ML/DL frameworks
# !pip install transformers==4.44.2
# !pip install accelerate==0.31.0
# !pip install peft==0.11.1
# !pip install datasets==3.5.0
# !pip install einops==0.8.0
# !pip install safetensors==0.4.3

# Scientific computing
# !pip install scipy==1.14.0
# !pip install pandas==1.4.3
# !pip install scikit-learn==1.1.1
# !pip install matplotlib==3.9.0
# !pip install bitsandbytes

# Web/API (optional for Colab)
# !pip install fastapi==0.115.11
# !pip install uvicorn==0.30.1
# !pip install gradio==5.20.0
# !pip install aiohttp==3.11.11

# Utilities
# !pip install tqdm==4.66.4
# !pip install pillow==10.3.0
# !pip install huggingface-hub==0.29.1
# !pip install pyyaml==6.0
# !pip install rich==14.0.0
# !pip install pydantic==2.7.4
# !pip install python-dotenv==1.0.1
# !pip install numba==0.60.0
# !pip install llvmlite==0.43.0
# !pip install uv
# !pip install openpyxl
# !pip install pydantic-settings
# !pip install cloudpathlib
# !pip install google-cloud-storage
# !pip install wandb
# !pip install tensorboard
# !pip install seaborn

# Audio evaluation
# !pip install mir-eval==0.7

# Step 4: Install beans-zero
print("\n[4/8] Installing beans-zero...")
# !pip install git+https://github.com/earthspecies/beans-zero.git@31d4487ee6452ae6c31853d45fd38b7d4150372d

# Step 5: Install NatureLM-audio
print("\n[5/8] Installing NatureLM-audio...")

# Navigate to NatureLMaudio directory
import os
from pathlib import Path

# Try to find NatureLMaudio
possible_paths = [
    "/content/drive/MyDrive/NatureLMaudio",
    str(Path.cwd() / "NatureLMaudio")
]

naturelm_path = None
for path in possible_paths:
    if os.path.exists(path):
        naturelm_path = path
        print(f"Found NatureLMaudio at: {naturelm_path}")
        break

if naturelm_path:
    original_dir = os.getcwd()
    os.chdir(naturelm_path)
    # !pip install -e .[gpu] --no-deps
    os.chdir(original_dir)
    print("NatureLM-audio installed")
else:
    print("Could not find NatureLMaudio directory")
    print("Please ensure it exists in one of these locations:")
    for path in possible_paths:
        print(f"  - {path}")

# Step 7: Clean pip cache
# !pip cache purge

# Navigate to the NatureLM-audio directory and install from there
import os

# Check where you are and where NatureLM-audio is
print("Current directory:", os.getcwd())
print("NatureLMaudio exists:", os.path.exists("NatureLMaudio"))

# Change to the NatureLMaudio directory and install
if os.path.exists("NatureLMaudio"):
  # %cd NatureLMaudio
  # Uncomment the install you want
  # !pip install -e . # For CPU install
  # !pip install -e .[gpu] --no-deps # For GPU install
  # %cd ..
else:
  print("NatureLMaudio directory not found in current path")
  
  # Try the full path
  naturelm_path = "/content/drive/MyDrive/NatureLMaudio"
  if os.path.exists(naturelm_path):
    # %cd "{naturelm_path}"
      
    # Uncomment the install you want
    # !pip install -e . # For CPU install
    # !pip install -e .[gpu] --no-deps # For GPU install
    # %cd /content
  else:
      print(f"NatureLMaudio not found at {naturelm_path}")
# Out:
# [1/8] Installing system dependencies...
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
#
# [2/8] Upgrading pip...
# ...
#
# [3/8] Installing Python dependencies with pinned versions...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 21.8 MB/s  0:00:00 eta 0:00:01
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> No available output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# ERROR: Failed to build 'pandas' when getting requirements to build wheel
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 19.8 MB/s  0:00:00 eta 0:00:01
#   Installing build dependencies ... done
# ...

# %% [markdown]
# # Install BEANS-Zero

# %%
# %cd ..

# Install beans-zero with dependency resolution ignoring conflicts
# !pip install --no-deps git+https://github.com/earthspecies/beans-zero.git@31d4487ee6452ae6c31853d45fd38b7d4150372d
# Out:
# /content/drive
# ...
#   Cloning https://github.com/earthspecies/beans-zero.git (to revision 31d4487ee6452ae6c31853d45fd38b7d4150372d) to /tmp/pip-req-build-4b674ycx
#   Running command git clone --filter=blob:none --quiet https://github.com/earthspecies/beans-zero.git /tmp/pip-req-build-4b674ycx
#   Running command git rev-parse -q --verify 'sha^31d4487ee6452ae6c31853d45fd38b7d4150372d'
#   Running command git fetch -q https://github.com/earthspecies/beans-zero.git 31d4487ee6452ae6c31853d45fd38b7d4150372d
#   Resolved https://github.com/earthspecies/beans-zero.git to commit 31d4487ee6452ae6c31853d45fd38b7d4150372d
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done

# %% [markdown]
# # Install bitsandbytes

# %%
# !pip install "rich<14"
# !pip install bitsandbytes
# Out:
# ...
#   Attempting uninstall: rich
#     Found existing installation: rich 14.0.0
#     Uninstalling rich-14.0.0:
#       Successfully uninstalled rich-14.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# naturelm-audio 1.0.2 requires memoization>=0.4.0, which is not installed.
# naturelm-audio 1.0.2 requires plumbum>=1.7.2, which is not installed.
# naturelm-audio 1.0.2 requires tensorboardx>=2.6.2.2, which is not installed.
# beans-zero 1.0.0 requires rich>=14.0.0, but you have rich 13.9.4 which is incompatible.
# ...

# %% [markdown]
# # Verification of some installs

# %%
import torch

print("Torch version:", torch.__version__)
if torch.cuda.is_available():
    print("CUDA available:", torch.cuda.is_available())
    print("GPU:", torch.cuda.get_device_name(0))

import bitsandbytes as bnb
print("bitsandbytes version:", bnb.__version__)
# Out:
# Torch version: 2.9.0+cu126
# CUDA available: True
# GPU: NVIDIA L4
# bitsandbytes version: 0.49.2

# %% [markdown]
# # Download Our Code

# %%
if os.path.exists("CS491-691-Adaptation-of-NatureLM-to-Unseen-Domains"):
  import shutil
  shutil.rmtree("CS491-691-Adaptation-of-NatureLM-to-Unseen-Domains")
# !git clone https://github.com/CarterAWebb827/CS491-691-Adaptation-of-NatureLM-to-Unseen-Domains.git
# Out:
# fatal: could not create work tree dir 'CS491-691-Adaptation-of-NatureLM-to-Unseen-Domains': Operation not supported

# %%
# %cd "/CS491-691-Adaptation-of-NatureLM-to-Unseen-Domains"
# !git checkout fasd13-animal-sounds
# !ls
# Out:
# /CS491-691-Adaptation-of-NatureLM-to-Unseen-Domains
# Already on 'fasd13-animal-sounds'
# Your branch is up to date with 'origin/fasd13-animal-sounds'.
# anura_dataset.py   __pycache__	      rfcx_zero_shot.py  zero_shot_fasd13.py
# fasd13_dataset.py  README.md	      setup.ipynb
# flowcharts	   rfcx_dataset.py    xeno_dataset.py
# outputs		   rfcx_fine_tune.py  xeno_zero_shot.py

# %%
from anura_dataset import AnuraDataset
from fasd13_dataset import FASD13Dataset

class Config():
    pass

config = Config()




anura = AnuraDataset(config)
fasd = FASD13Dataset(config)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-979186066.py in <cell line: 0>()
#       2 from fasd13_dataset import FASD13Dataset
#       3
# ----> 4 class Config:
#       5     self.data_dir = "/content/drive/MyDrive/FASD13"
#       6     self.sample_rate = 16000
#
# /tmp/ipython-input-979186066.py in Config()
#       3
#       4 class Config:
# ----> 5     self.data_dir = "/content/drive/MyDrive/FASD13"
#       6     self.sample_rate = 16000
#       7     self.max_length = 10
#
# NameError: name 'self' is not defined

# %% [markdown]
# # Edit the YAML

# %%
import yaml

# Path to your YAML file
yaml_path = f"{naturelm_drive_path}/configs/finetune_anura.yaml"

# Load the YAML
with open(yaml_path, 'r') as f:
    config = yaml.safe_load(f)

# Update paths to use mounted locations
config["model"]["beats_path"] = f"{naturelm_drive_path}/models/beats/BEATs_iter3_plus_AS2M_finetuned_on_AS2M_cpt2.pt"
config["datasets"]["train_ann_path"] = f"{naturelm_drive_path}/NatureLM/dummy.jsonl"
config["datasets"]["valid_ann_path"] = f"{naturelm_drive_path}/NatureLM/dummy.jsonl"
config["datasets"]["test_ann_path"] = f"{naturelm_drive_path}/NatureLM/dummy.jsonl"

# %% [markdown]
# # Run Program

# %%
# !python CS491-691-Adaptation-of-NatureLM-to-Unseen-Domains/fine_tune.py --data_dir "{data_drive_path}"
