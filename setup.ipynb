# %% [markdown]
# # Install System Dependencies

# %%
import importlib.metadata as importlib_metadata
import os
import subprocess
import sys

TARGET_VERSIONS = {
    "numpy": "1.26.4",
    "pandas": "2.2.2",
}

restart_required = False

for package_name, target_version in TARGET_VERSIONS.items():
    try:
        current_version = importlib_metadata.version(package_name)
    except importlib_metadata.PackageNotFoundError:
        current_version = None

    if current_version != target_version:
        restart_required = True
        subprocess.check_call([
            sys.executable,
            "-m",
            "pip",
            "install",
            "--upgrade",
            "--force-reinstall",
            "--no-cache-dir",
            f"{package_name}=={target_version}",
        ])

if restart_required:
    print("Restarting runtime to finish loading updated numpy/pandas...")
    os.kill(os.getpid(), 9)
else:
    print("numpy and pandas already match the pinned versions.")
# Out:
# numpy and pandas already match the pinned versions.

# %%
import numpy as np
import pandas as pd

print (np.__version__)
print (pd.__version__)


# !apt-get update -qq
# !apt-get install -y -qq \
    libsndfile1 \
    ffmpeg \
    libavcodec-extra \
    build-essential \
    cmake \
    swig
# Out:
# 1.26.4
# 2.2.2
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Selecting previously unselected package libaribb24-0:amd64.
# (Reading database ... 122354 files and directories currently installed.)
# Preparing to unpack .../libaribb24-0_1.0.3-2_amd64.deb ...
# Unpacking libaribb24-0:amd64 (1.0.3-2) ...
# Selecting previously unselected package libopencore-amrnb0:amd64.
# Preparing to unpack .../libopencore-amrnb0_0.1.5-1_amd64.deb ...
# Unpacking libopencore-amrnb0:amd64 (0.1.5-1) ...
# Selecting previously unselected package libopencore-amrwb0:amd64.
# Preparing to unpack .../libopencore-amrwb0_0.1.5-1_amd64.deb ...
# Unpacking libopencore-amrwb0:amd64 (0.1.5-1) ...
# Selecting previously unselected package libvo-amrwbenc0:amd64.
# Preparing to unpack .../libvo-amrwbenc0_0.1.3-2_amd64.deb ...
# Unpacking libvo-amrwbenc0:amd64 (0.1.3-2) ...
# dpkg: libavcodec58:amd64: dependency problems, but removing anyway as you requested:
#  libchromaprint1:amd64 depends on libavcodec58 (>= 7:4.4).
#  libavformat58:amd64 depends on libavcodec58 (= 7:4.4.2-0ubuntu0.22.04.1).
#  libavfilter7:amd64 depends on libavcodec58 (= 7:4.4.2-0ubuntu0.22.04.1).
#  libavdevice58:amd64 depends on libavcodec58 (= 7:4.4.2-0ubuntu0.22.04.1).
#  ffmpeg depends on libavcodec58 (= 7:4.4.2-0ubuntu0.22.04.1).
#
# (Reading database ... 122378 files and directories currently installed.)
# Removing libavcodec58:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Selecting previously unselected package libavcodec-extra58:amd64.
# (Reading database ... 122372 files and directories currently installed.)
# Preparing to unpack .../libavcodec-extra58_7%3a4.4.2-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libavcodec-extra58:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Selecting previously unselected package swig4.0.
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Selecting previously unselected package libavcodec-extra:amd64.
# Preparing to unpack .../libavcodec-extra_7%3a4.4.2-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libavcodec-extra:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libvo-amrwbenc0:amd64 (0.1.3-2) ...
# Setting up libaribb24-0:amd64 (1.0.3-2) ...
# Setting up libopencore-amrwb0:amd64 (0.1.5-1) ...
# Setting up libopencore-amrnb0:amd64 (0.1.5-1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Setting up libavcodec-extra58:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libavcodec-extra:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link

# %% [markdown]
# # Clone/Mount NatureLM Repo

# %%
# !git clone https://github.com/earthspecies/NatureLM-audio.github

from google.colab import drive
drive.mount('/content/drive')

import os
naturelm_path = "/content/drive/MyDrive/NatureLMaudio"
data_path = "/content/drive/MyDrive/AnuraSet"

# Create symlinks in the current working directory
if not os.path.exists("NatureLMaudio"):
    # !ln -s "{naturelm_path}" NatureLMaudio

if not os.path.exists("data"):
    os.makedirs("data", exist_ok=True)
    # !ln -s "{dataf_path}" data/AnuraSet

# %cd NatureLMaudio
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/NatureLMaudio

# %% [markdown]
# # Upgrade pip and install NatureLM CPU or GPU version

# %%
# Step 1: System dependencies
print("\n[1/8] Installing system dependencies...")
# !apt-get update -qq
# !apt-get install -y -qq \
    python3-tk \
    libopenblas-dev \
    libomp-dev \
    curl \
    git \
    cmake \
    build-essential \
    swig \
    libsndfile1 \
    ffmpeg \
    libavcodec-extra

# Step 2: Upgrade pip
print("\n[2/8] Upgrading pip...")
# !pip install --upgrade pip

# Step 3: Install Python dependencies with EXACT versions from your environment
print("\n[3/8] Installing Python dependencies with pinned versions...")

# Core dependencies
# !pip install numpy==1.26.4

# Audio processing
# !pip install librosa==0.9.2
# !pip install soundfile==0.12.1
# !pip install audioread==3.0.1
# !pip install resampy==0.3.1
# !pip install pydub==0.25.1

# ML/DL frameworks
# !pip install transformers==4.44.2
# !pip install accelerate==0.31.0
# !pip install peft==0.11.1
# !pip install datasets==3.5.0
# !pip install einops==0.8.0
# !pip install safetensors==0.4.3

# Scientific computing
# !pip install scipy==1.14.0
# !pip install pandas==1.4.3
# !pip install scikit-learn==1.1.1
# !pip install matplotlib==3.9.0
# !pip install bitsandbytes

# Web/API (optional for Colab)
# !pip install fastapi==0.115.11
# !pip install uvicorn==0.30.1
# !pip install gradio==5.20.0
# !pip install aiohttp==3.11.11

# Utilities
# !pip install tqdm==4.66.4
# !pip install pillow==10.3.0
# !pip install huggingface-hub==0.29.1
# !pip install pyyaml==6.0
# !pip install rich==14.0.0
# !pip install pydantic==2.7.4
# !pip install python-dotenv==1.0.1
# !pip install numba==0.60.0
# !pip install llvmlite==0.43.0
# !pip install uv
# !pip install openpyxl
# !pip install pydantic-settings
# !pip install cloudpathlib
# !pip install google-cloud-storage
# !pip install wandb
# !pip install tensorboard
# !pip install seaborn

# Audio evaluation
# !pip install mir-eval==0.7

# Step 4: Install beans-zero
print("\n[4/8] Installing beans-zero...")
# !pip install git+https://github.com/earthspecies/beans-zero.git@31d4487ee6452ae6c31853d45fd38b7d4150372d

# Step 5: Install NatureLM-audio
print("\n[5/8] Installing NatureLM-audio...")

# Step 7: Clean pip cache
# !pip cache purge

# Change to the NatureLMaudio directory and install
if os.path.exists("NatureLMaudio"):
  # %cd NatureLMaudio
  # Uncomment the install you want
  # !pip install -e . # For CPU install
  # !pip install -e .[gpu] --no-deps # For GPU install
  # %cd ..
else:
  print("NatureLMaudio directory not found in current path")
# Out:
# [1/8] Installing system dependencies...
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Selecting previously unselected package tk8.6-blt2.5.
# (Reading database ... 123134 files and directories currently installed.)
# Preparing to unpack .../0-tk8.6-blt2.5_2.5.3+dfsg-4.1build2_amd64.deb ...
# Unpacking tk8.6-blt2.5 (2.5.3+dfsg-4.1build2) ...
# Selecting previously unselected package blt.
# Preparing to unpack .../1-blt_2.5.3+dfsg-4.1build2_amd64.deb ...
# Unpacking blt (2.5.3+dfsg-4.1build2) ...
# Selecting previously unselected package libllvm14:amd64.
# Preparing to unpack .../2-libllvm14_1%3a14.0.0-1ubuntu1.1_amd64.deb ...
# Unpacking libllvm14:amd64 (1:14.0.0-1ubuntu1.1) ...
# Selecting previously unselected package libomp5-14:amd64.
# Preparing to unpack .../3-libomp5-14_1%3a14.0.0-1ubuntu1.1_amd64.deb ...
# Unpacking libomp5-14:amd64 (1:14.0.0-1ubuntu1.1) ...
# Selecting previously unselected package libomp-14-dev.
# Preparing to unpack .../4-libomp-14-dev_1%3a14.0.0-1ubuntu1.1_amd64.deb ...
# Unpacking libomp-14-dev (1:14.0.0-1ubuntu1.1) ...
# Selecting previously unselected package python3-tk:amd64.
# Preparing to unpack .../5-python3-tk_3.10.8-1~22.04_amd64.deb ...
# Unpacking python3-tk:amd64 (3.10.8-1~22.04) ...
# Selecting previously unselected package libomp-dev:amd64.
# Preparing to unpack .../6-libomp-dev_1%3a14.0-55~exp2_amd64.deb ...
# Unpacking libomp-dev:amd64 (1:14.0-55~exp2) ...
# Setting up libomp5-14:amd64 (1:14.0.0-1ubuntu1.1) ...
# Setting up tk8.6-blt2.5 (2.5.3+dfsg-4.1build2) ...
# Setting up blt (2.5.3+dfsg-4.1build2) ...
# Setting up python3-tk:amd64 (3.10.8-1~22.04) ...
# Setting up libllvm14:amd64 (1:14.0.0-1ubuntu1.1) ...
# Setting up libomp-14-dev (1:14.0.0-1ubuntu1.1) ...
# Setting up libomp-dev:amd64 (1:14.0-55~exp2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
#
# [2/8] Upgrading pip...
# Requirement already satisfied: pip in /usr/local/lib/python3.12/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-26.0.1-py3-none-any.whl.metadata (4.7 kB)
# Downloading pip-26.0.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 41.2 MB/s eta 0:00:0000:01
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# Successfully installed pip-26.0.1
#
# [3/8] Installing Python dependencies with pinned versions...
# Requirement already satisfied: numpy==1.26.4 in /usr/local/lib/python3.12/dist-packages (1.26.4)
# Collecting librosa==0.9.2
#   Downloading librosa-0.9.2-py3-none-any.whl.metadata (8.2 kB)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa==0.9.2) (3.1.0)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.9.2) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.9.2) (1.16.3)
# Requirement already satisfied: scikit-learn>=0.19.1 in /usr/local/lib/python3.12/dist-packages (from librosa==0.9.2) (1.6.1)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.12/dist-packages (from librosa==0.9.2) (1.5.3)
# Requirement already satisfied: decorator>=4.0.10 in /usr/local/lib/python3.12/dist-packages (from librosa==0.9.2) (4.4.2)
# Collecting resampy>=0.2.2 (from librosa==0.9.2)
#   Downloading resampy-0.4.3-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: numba>=0.45.1 in /usr/local/lib/python3.12/dist-packages (from librosa==0.9.2) (0.60.0)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.12/dist-packages (from librosa==0.9.2) (0.13.1)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.9.2) (1.9.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from librosa==0.9.2) (26.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.45.1->librosa==0.9.2) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.0->librosa==0.9.2) (4.9.4)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.0->librosa==0.9.2) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.2) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa==0.9.2) (2026.2.25)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=0.19.1->librosa==0.9.2) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile>=0.10.2->librosa==0.9.2) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa==0.9.2) (3.0)
# Downloading librosa-0.9.2-py3-none-any.whl (214 kB)
# Downloading resampy-0.4.3-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 17.4 MB/s  0:00:00
# Installing collected packages: resampy, librosa
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.11.0
#     Uninstalling librosa-0.11.0:
#       Successfully uninstalled librosa-0.11.0
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [librosa]m1/2 [librosa]
# Successfully installed librosa-0.9.2 resampy-0.4.3
# Collecting soundfile==0.12.1
#   Downloading soundfile-0.12.1-py2.py3-none-manylinux_2_31_x86_64.whl.metadata (14 kB)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile==0.12.1) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile==0.12.1) (3.0)
# Downloading soundfile-0.12.1-py2.py3-none-manylinux_2_31_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 13.2 MB/s  0:00:00
# Installing collected packages: soundfile
#   Attempting uninstall: soundfile
#     Found existing installation: soundfile 0.13.1
#     Uninstalling soundfile-0.13.1:
#       Successfully uninstalled soundfile-0.13.1
# Successfully installed soundfile-0.12.1
# Collecting audioread==3.0.1
#   Downloading audioread-3.0.1-py3-none-any.whl.metadata (8.4 kB)
# Downloading audioread-3.0.1-py3-none-any.whl (23 kB)
# Installing collected packages: audioread
#   Attempting uninstall: audioread
#     Found existing installation: audioread 3.1.0
#     Uninstalling audioread-3.1.0:
#       Successfully uninstalled audioread-3.1.0
# Successfully installed audioread-3.0.1
# Collecting resampy==0.3.1
#   Downloading resampy-0.3.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from resampy==0.3.1) (1.26.4)
# Requirement already satisfied: numba>=0.47 in /usr/local/lib/python3.12/dist-packages (from resampy==0.3.1) (0.60.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.47->resampy==0.3.1) (0.43.0)
# Downloading resampy-0.3.1-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 15.0 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: resampy
#   Attempting uninstall: resampy
#     Found existing installation: resampy 0.4.3
#     Uninstalling resampy-0.4.3:
#       Successfully uninstalled resampy-0.4.3
# Successfully installed resampy-0.3.1
# Requirement already satisfied: pydub==0.25.1 in /usr/local/lib/python3.12/dist-packages (0.25.1)
# Collecting transformers==4.44.2
#   Downloading transformers-4.44.2-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.44.2) (3.25.2)
# Collecting huggingface-hub<1.0,>=0.23.2 (from transformers==4.44.2)
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.44.2) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.44.2) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.44.2) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.44.2) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.44.2) (2.32.4)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.44.2) (0.7.0)
# Collecting tokenizers<0.20,>=0.19 (from transformers==4.44.2)
#   Downloading tokenizers-0.19.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers==4.44.2) (4.67.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.44.2) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.44.2) (1.4.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers==4.44.2) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.44.2) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.44.2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.44.2) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.44.2) (2026.2.25)
# Downloading transformers-4.44.2-py3-none-any.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 29.2 MB/s  0:00:00 eta 0:00:01
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 19.6 MB/s  0:00:00
# Downloading tokenizers-0.19.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 64.5 MB/s  0:00:00
# Installing collected packages: huggingface-hub, tokenizers, transformers
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.7.1
#     Uninstalling huggingface_hub-1.7.1:
#       Successfully uninstalled huggingface_hub-1.7.1
#   Attempting uninstall: tokenizers━━━━━━━━━━━━━━ 0/3 [huggingface-hub]
#     Found existing installation: tokenizers 0.22.20/3 [huggingface-hub]
#     Uninstalling tokenizers-0.22.2:━━━━━━━━━ 0/3 [huggingface-hub]
#       Successfully uninstalled tokenizers-0.22.2━━━━━━━━━━━━━━━━━━ 1/3 [tokenizers]
#   Attempting uninstall: transformers━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/3 [tokenizers]
#     Found existing installation: transformers 5.0.0━━━━━━━━━━━ 1/3 [tokenizers]
#     Uninstalling transformers-5.0.0:0m╸━━━━━━━━━━━━━ 2/3 [transformers]
#       Successfully uninstalled transformers-5.0.0━━━━━━━━━━━━━ 2/3 [transformers]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [transformers] [transformers]
# Successfully installed huggingface-hub-0.36.2 tokenizers-0.19.1 transformers-4.44.2
# Collecting accelerate==0.31.0
#   Downloading accelerate-0.31.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from accelerate==0.31.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from accelerate==0.31.0) (26.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate==0.31.0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from accelerate==0.31.0) (6.0.3)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from accelerate==0.31.0) (2.10.0+cu128)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.12/dist-packages (from accelerate==0.31.0) (0.36.2)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from accelerate==0.31.0) (0.7.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.10.0->accelerate==0.31.0) (1.4.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.10.0->accelerate==0.31.0) (1.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->accelerate==0.31.0) (1.4.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->accelerate==0.31.0) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub->accelerate==0.31.0) (4.67.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.10.0->accelerate==0.31.0) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->accelerate==0.31.0) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->accelerate==0.31.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->accelerate==0.31.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub->accelerate==0.31.0) (2026.2.25)
# Downloading accelerate-0.31.0-py3-none-any.whl (309 kB)
# Installing collected packages: accelerate
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 1.13.0
#     Uninstalling accelerate-1.13.0:
#       Successfully uninstalled accelerate-1.13.0
# Successfully installed accelerate-0.31.0
# Collecting peft==0.11.1
#   Downloading peft-0.11.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from peft==0.11.1) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from peft==0.11.1) (26.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from peft==0.11.1) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from peft==0.11.1) (6.0.3)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from peft==0.11.1) (2.10.0+cu128)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from peft==0.11.1) (4.44.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from peft==0.11.1) (4.67.3)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from peft==0.11.1) (0.31.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from peft==0.11.1) (0.7.0)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /usr/local/lib/python3.12/dist-packages (from peft==0.11.1) (0.36.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.17.0->peft==0.11.1) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.17.0->peft==0.11.1) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.17.0->peft==0.11.1) (1.4.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.17.0->peft==0.11.1) (2.32.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.17.0->peft==0.11.1) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft==0.11.1) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.13.0->peft==0.11.1) (1.4.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.13.0->peft==0.11.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.13.0->peft==0.11.1) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.17.0->peft==0.11.1) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.17.0->peft==0.11.1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.17.0->peft==0.11.1) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub>=0.17.0->peft==0.11.1) (2026.2.25)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->peft==0.11.1) (2025.11.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.12/dist-packages (from transformers->peft==0.11.1) (0.19.1)
# Downloading peft-0.11.1-py3-none-any.whl (251 kB)
# Installing collected packages: peft
#   Attempting uninstall: peft
#     Found existing installation: peft 0.18.1
#     Uninstalling peft-0.18.1:
#       Successfully uninstalled peft-0.18.1
# Successfully installed peft-0.11.1
# Collecting datasets==3.5.0
#   Downloading datasets-3.5.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets==3.5.0) (3.25.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets==3.5.0) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets==3.5.0) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets==3.5.0) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets==3.5.0) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets==3.5.0) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets==3.5.0) (4.67.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets==3.5.0) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets==3.5.0) (0.70.16)
# Collecting fsspec<=2024.12.0,>=2023.1.0 (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets==3.5.0)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from datasets==3.5.0) (3.13.3)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets==3.5.0) (0.36.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets==3.5.0) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets==3.5.0) (6.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==3.5.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==3.5.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==3.5.0) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==3.5.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==3.5.0) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==3.5.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets==3.5.0) (1.23.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp->datasets==3.5.0) (3.11)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.4.0->aiohttp->datasets==3.5.0) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets==3.5.0) (1.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==3.5.0) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==3.5.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==3.5.0) (2026.2.25)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==3.5.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==3.5.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==3.5.0) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets==3.5.0) (1.17.0)
# Downloading datasets-3.5.0-py3-none-any.whl (491 kB)
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
# Installing collected packages: fsspec, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.0
#     Uninstalling fsspec-2025.3.0:
#       Successfully uninstalled fsspec-2025.3.0
#   Attempting uninstall: datasets━━━━━━━━━━━━━━━━ 0/2 [fsspec]
#     Found existing installation: datasets 4.0.0m 0/2 [fsspec]
#     Uninstalling datasets-4.0.0:━━━━━━━━━━━━ 0/2 [fsspec]
#       Successfully uninstalled datasets-4.0.0 0/2 [fsspec]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [datasets]1/2 [datasets]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2024.12.0 which is incompatible.
# Successfully installed datasets-3.5.0 fsspec-2024.12.0
# Collecting einops==0.8.0
#   Downloading einops-0.8.0-py3-none-any.whl.metadata (12 kB)
# Downloading einops-0.8.0-py3-none-any.whl (43 kB)
# Installing collected packages: einops
#   Attempting uninstall: einops
#     Found existing installation: einops 0.8.2
#     Uninstalling einops-0.8.2:
#       Successfully uninstalled einops-0.8.2
# Successfully installed einops-0.8.0
# Collecting safetensors==0.4.3
#   Downloading safetensors-0.4.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Downloading safetensors-0.4.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 15.2 MB/s  0:00:00
# Installing collected packages: safetensors
#   Attempting uninstall: safetensors
#     Found existing installation: safetensors 0.7.0
#     Uninstalling safetensors-0.7.0:
#       Successfully uninstalled safetensors-0.7.0
# Successfully installed safetensors-0.4.3
# Collecting scipy==1.14.0
#   Downloading scipy-1.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in /usr/local/lib/python3.12/dist-packages (from scipy==1.14.0) (1.26.4)
# Downloading scipy-1.14.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (40.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/40.8 MB 58.7 MB/s  0:00:00m0:00:0100:01
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.3
#     Uninstalling scipy-1.16.3:
#       Successfully uninstalled scipy-1.16.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# access 1.1.10.post3 requires scipy>=1.14.1, but you have scipy 1.14.0 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed scipy-1.14.0
# Collecting pandas==1.4.3
#   Downloading pandas-1.4.3.tar.gz (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 15.2 MB/s  0:00:00 eta 0:00:01
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> No available output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# ERROR: Failed to build 'pandas' when getting requirements to build wheel
# Collecting scikit-learn==1.1.1
#   Downloading scikit-learn-1.1.1.tar.gz (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 25.5 MB/s  0:00:00 eta 0:00:01
#   Installing build dependencies ... done
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> No available output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Getting requirements to build wheel ... error
# ERROR: Failed to build 'scikit-learn' when getting requirements to build wheel
# Collecting matplotlib==3.9.0
#   Downloading matplotlib-3.9.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.0) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.0) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.0) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib==3.9.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib==3.9.0) (1.17.0)
# Downloading matplotlib-3.9.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 31.5 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: matplotlib
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.0
#     Uninstalling matplotlib-3.10.0:
#       Successfully uninstalled matplotlib-3.10.0
# Successfully installed matplotlib-3.9.0
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: torch<3,>=2.3 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (2.10.0+cu128)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (26.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2024.12.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch<3,>=2.3->bitsandbytes) (1.4.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3,>=2.3->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3,>=2.3->bitsandbytes) (3.0.3)
# Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl (60.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 89.6 MB/s  0:00:006m0:00:010:01
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.49.2
# Collecting fastapi==0.115.11
#   Downloading fastapi-0.115.11-py3-none-any.whl.metadata (27 kB)
# Collecting starlette<0.47.0,>=0.40.0 (from fastapi==0.115.11)
#   Downloading starlette-0.46.2-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4 in /usr/local/lib/python3.12/dist-packages (from fastapi==0.115.11) (2.12.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from fastapi==0.115.11) (4.15.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi==0.115.11) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi==0.115.11) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic!=1.8,!=1.8.1,!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.7.4->fastapi==0.115.11) (0.4.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.12/dist-packages (from starlette<0.47.0,>=0.40.0->fastapi==0.115.11) (4.12.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.6.2->starlette<0.47.0,>=0.40.0->fastapi==0.115.11) (3.11)
# Downloading fastapi-0.115.11-py3-none-any.whl (94 kB)
# Downloading starlette-0.46.2-py3-none-any.whl (72 kB)
# Installing collected packages: starlette, fastapi
#   Attempting uninstall: starlette
#     Found existing installation: starlette 0.52.1
#     Uninstalling starlette-0.52.1:
#       Successfully uninstalled starlette-0.52.1
#   Attempting uninstall: fastapi
#     Found existing installation: fastapi 0.135.1
#     Uninstalling fastapi-0.135.1:
#       Successfully uninstalled fastapi-0.135.1m━━━━━━━━━━━━━━━━━━━ 1/2 [fastapi]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [fastapi] [fastapi]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-adk 1.27.1 requires fastapi<1.0.0,>=0.124.1, but you have fastapi 0.115.11 which is incompatible.
# google-adk 1.27.1 requires starlette<1.0.0,>=0.49.1, but you have starlette 0.46.2 which is incompatible.
# sse-starlette 3.3.2 requires starlette>=0.49.1, but you have starlette 0.46.2 which is incompatible.
# Successfully installed fastapi-0.115.11 starlette-0.46.2
# Collecting uvicorn==0.30.1
#   Downloading uvicorn-0.30.1-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from uvicorn==0.30.1) (8.3.1)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn==0.30.1) (0.16.0)
# Downloading uvicorn-0.30.1-py3-none-any.whl (62 kB)
# Installing collected packages: uvicorn
#   Attempting uninstall: uvicorn
#     Found existing installation: uvicorn 0.42.0
#     Uninstalling uvicorn-0.42.0:
#       Successfully uninstalled uvicorn-0.42.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-adk 1.27.1 requires fastapi<1.0.0,>=0.124.1, but you have fastapi 0.115.11 which is incompatible.
# google-adk 1.27.1 requires starlette<1.0.0,>=0.49.1, but you have starlette 0.46.2 which is incompatible.
# google-adk 1.27.1 requires uvicorn<1.0.0,>=0.34.0, but you have uvicorn 0.30.1 which is incompatible.
# mcp 1.26.0 requires uvicorn>=0.31.1; sys_platform != "emscripten", but you have uvicorn 0.30.1 which is incompatible.
# Successfully installed uvicorn-0.30.1
# Collecting gradio==5.20.0
#   Downloading gradio-5.20.0-py3-none-any.whl.metadata (16 kB)
# Collecting aiofiles<24.0,>=22.0 (from gradio==5.20.0)
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.20.0) (4.12.1)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio==5.20.0) (0.115.11)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio==5.20.0) (1.0.0)
# Collecting gradio-client==1.7.2 (from gradio==5.20.0)
#   Downloading gradio_client-1.7.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio==5.20.0) (0.1.2)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio==5.20.0) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from gradio==5.20.0) (0.36.2)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.20.0) (3.1.6)
# Collecting markupsafe~=2.0 (from gradio==5.20.0)
#   Downloading MarkupSafe-2.1.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.20.0) (1.26.4)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.20.0) (3.11.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from gradio==5.20.0) (26.0)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.20.0) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.20.0) (11.3.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.20.0) (2.12.3)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio==5.20.0) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio==5.20.0) (0.0.22)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.20.0) (6.0.3)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio==5.20.0) (0.15.6)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio==5.20.0) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.20.0) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.20.0) (0.46.2)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio==5.20.0) (0.13.3)
# ...
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.12/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.12/dist-packages (from seaborn) (3.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Collecting mir-eval==0.7
#   Downloading mir_eval-0.7.tar.gz (90 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from mir-eval==0.7) (1.26.4)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from mir-eval==0.7) (1.14.0)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from mir-eval==0.7) (1.0.0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from mir-eval==0.7) (1.17.0)
# Building wheels for collected packages: mir-eval
#   Building wheel for mir-eval (pyproject.toml) ... done
#   Created wheel for mir-eval: filename=mir_eval-0.7-py3-none-any.whl size=100768 sha256=27e7e79fc0a0101e04f4a45c5df7740cd7e6c607b09327a3dc107b84c60f5098
#   Stored in directory: /root/.cache/pip/wheels/8d/99/b2/ddfa8da66ccb760e700a925b53954fa76f5b31c999e42c29f3
# Successfully built mir-eval
# Installing collected packages: mir-eval
# Successfully installed mir-eval-0.7
#
# [4/8] Installing beans-zero...
# Collecting git+https://github.com/earthspecies/beans-zero.git@31d4487ee6452ae6c31853d45fd38b7d4150372d
#   Cloning https://github.com/earthspecies/beans-zero.git (to revision 31d4487ee6452ae6c31853d45fd38b7d4150372d) to /tmp/pip-req-build-ab6yh2vi
#   Running command git clone --filter=blob:none --quiet https://github.com/earthspecies/beans-zero.git /tmp/pip-req-build-ab6yh2vi
#   Running command git rev-parse -q --verify 'sha^31d4487ee6452ae6c31853d45fd38b7d4150372d'
#   Running command git fetch -q https://github.com/earthspecies/beans-zero.git 31d4487ee6452ae6c31853d45fd38b7d4150372d
#   Resolved https://github.com/earthspecies/beans-zero.git to commit 31d4487ee6452ae6c31853d45fd38b7d4150372d
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: click>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from beans-zero==1.0.0) (8.3.1)
# Requirement already satisfied: datasets>=3.4.0 in /usr/local/lib/python3.12/dist-packages (from beans-zero==1.0.0) (3.5.0)
# Collecting levenshtein>=0.27.1 (from beans-zero==1.0.0)
#   Downloading levenshtein-0.27.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (3.7 kB)
# Requirement already satisfied: pytest>=8.3.5 in /usr/local/lib/python3.12/dist-packages (from beans-zero==1.0.0) (8.4.2)
# Requirement already satisfied: rich>=14.0.0 in /usr/local/lib/python3.12/dist-packages (from beans-zero==1.0.0) (14.0.0)
# Requirement already satisfied: scikit-learn>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from beans-zero==1.0.0) (1.6.1)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from beans-zero==1.0.0) (2.10.0+cu128)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=3.4.0->beans-zero==1.0.0) (3.25.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.4.0->beans-zero==1.0.0) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.4.0->beans-zero==1.0.0) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.4.0->beans-zero==1.0.0) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets>=3.4.0->beans-zero==1.0.0) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.4.0->beans-zero==1.0.0) (2.32.4)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.4.0->beans-zero==1.0.0) (4.66.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=3.4.0->beans-zero==1.0.0) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.4.0->beans-zero==1.0.0) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets>=3.4.0->beans-zero==1.0.0) (2024.12.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from datasets>=3.4.0->beans-zero==1.0.0) (3.11.11)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.4.0->beans-zero==1.0.0) (0.29.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets>=3.4.0->beans-zero==1.0.0) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.4.0->beans-zero==1.0.0) (6.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets>=3.4.0->beans-zero==1.0.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets>=3.4.0->beans-zero==1.0.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets>=3.4.0->beans-zero==1.0.0) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets>=3.4.0->beans-zero==1.0.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets>=3.4.0->beans-zero==1.0.0) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets>=3.4.0->beans-zero==1.0.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->datasets>=3.4.0->beans-zero==1.0.0) (1.23.0)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp->datasets>=3.4.0->beans-zero==1.0.0) (3.11)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.1.2->aiohttp->datasets>=3.4.0->beans-zero==1.0.0) (4.15.0)
# Collecting rapidfuzz<4.0.0,>=3.9.0 (from levenshtein>=0.27.1->beans-zero==1.0.0)
#   Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: iniconfig>=1 in /usr/local/lib/python3.12/dist-packages (from pytest>=8.3.5->beans-zero==1.0.0) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest>=8.3.5->beans-zero==1.0.0) (1.6.0)
# Requirement already satisfied: pygments>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from pytest>=8.3.5->beans-zero==1.0.0) (2.19.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=3.4.0->beans-zero==1.0.0) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=3.4.0->beans-zero==1.0.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=3.4.0->beans-zero==1.0.0) (2026.2.25)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=14.0.0->beans-zero==1.0.0) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=14.0.0->beans-zero==1.0.0) (0.1.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.1->beans-zero==1.0.0) (1.14.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.1->beans-zero==1.0.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.1->beans-zero==1.0.0) (3.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->beans-zero==1.0.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->beans-zero==1.0.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->beans-zero==1.0.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->beans-zero==1.0.0) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->beans-zero==1.0.0) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->beans-zero==1.0.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->beans-zero==1.0.0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->beans-zero==1.0.0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->beans-zero==1.0.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->beans-zero==1.0.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->beans-zero==1.0.0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->beans-zero==1.0.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->beans-zero==1.0.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->beans-zero==1.0.0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->beans-zero==1.0.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->beans-zero==1.0.0) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->beans-zero==1.0.0) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->beans-zero==1.0.0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->beans-zero==1.0.0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->beans-zero==1.0.0) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->beans-zero==1.0.0) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.0.0->beans-zero==1.0.0) (1.4.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->beans-zero==1.0.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->beans-zero==1.0.0) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=3.4.0->beans-zero==1.0.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=3.4.0->beans-zero==1.0.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=3.4.0->beans-zero==1.0.0) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=3.4.0->beans-zero==1.0.0) (1.17.0)
# Downloading levenshtein-0.27.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (153 kB)
# Downloading rapidfuzz-3.14.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 17.1 MB/s  0:00:00
# Building wheels for collected packages: beans-zero
#   Building wheel for beans-zero (pyproject.toml) ... done
#   Created wheel for beans-zero: filename=beans_zero-1.0.0-py3-none-any.whl size=30789805 sha256=86e72c483f429048c59549f00a0be757f938baea4922507b44c7faa6b47bd9f2
#   Stored in directory: /root/.cache/pip/wheels/84/8d/47/fc4ad818daebbe77549472d096eb9eca9f4df49ffd47ebfd2b
# Successfully built beans-zero
# Installing collected packages: rapidfuzz, levenshtein, beans-zero
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [beans-zero]3 [beans-zero]
# Successfully installed beans-zero-1.0.0 levenshtein-0.27.3 rapidfuzz-3.14.3
#
# [5/8] Installing NatureLM-audio...
# Files removed: 306 (349.3 MB)
# Directories removed: 9
# /content/drive/MyDrive/NatureLMaudio
# Obtaining file:///content/drive/MyDrive/NatureLMaudio
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Installing backend dependencies ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Building wheels for collected packages: NatureLM-audio
#   Building editable for NatureLM-audio (pyproject.toml) ... done
#   Created wheel for NatureLM-audio: filename=naturelm_audio-1.0.2-py3-none-any.whl size=5117 sha256=14bbd0406213328138287f78de2dcc8fce769c905dc637767907eec6c61b0028
#   Stored in directory: /tmp/pip-ephem-wheel-cache-c7in6uul/wheels/99/7a/05/e99ebdde7be350ad3d442582498d0616d7e07406221e707d2e
# Successfully built NatureLM-audio
# Installing collected packages: NatureLM-audio
# Successfully installed NatureLM-audio-1.0.2
# /content/drive/MyDrive

# %% [markdown]
# # Install BEANS-Zero

# %%
# %cd ..

# Install beans-zero with dependency resolution ignoring conflicts
# !pip install --no-deps git+https://github.com/earthspecies/beans-zero.git@31d4487ee6452ae6c31853d45fd38b7d4150372d
# Out:
# /content/drive
# Collecting git+https://github.com/earthspecies/beans-zero.git@31d4487ee6452ae6c31853d45fd38b7d4150372d
#   Cloning https://github.com/earthspecies/beans-zero.git (to revision 31d4487ee6452ae6c31853d45fd38b7d4150372d) to /tmp/pip-req-build-k8yr6g_j
#   Running command git clone --filter=blob:none --quiet https://github.com/earthspecies/beans-zero.git /tmp/pip-req-build-k8yr6g_j
#   Running command git rev-parse -q --verify 'sha^31d4487ee6452ae6c31853d45fd38b7d4150372d'
#   Running command git fetch -q https://github.com/earthspecies/beans-zero.git 31d4487ee6452ae6c31853d45fd38b7d4150372d
#   Resolved https://github.com/earthspecies/beans-zero.git to commit 31d4487ee6452ae6c31853d45fd38b7d4150372d
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done

# %% [markdown]
# # Install bitsandbytes

# %%
# !pip install "rich<14"
# !pip install bitsandbytes
# Out:
# Collecting rich<14
#   Downloading rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich<14) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich<14) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich<14) (0.1.2)
# Downloading rich-13.9.4-py3-none-any.whl (242 kB)
# Installing collected packages: rich
#   Attempting uninstall: rich
#     Found existing installation: rich 14.0.0
#     Uninstalling rich-14.0.0:
#       Successfully uninstalled rich-14.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# beans-zero 1.0.0 requires rich>=14.0.0, but you have rich 13.9.4 which is incompatible.
# Successfully installed rich-13.9.4
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.12/dist-packages (0.49.2)
# Requirement already satisfied: torch<3,>=2.3 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (2.10.0+cu128)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (26.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2024.12.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch<3,>=2.3->bitsandbytes) (1.4.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3,>=2.3->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3,>=2.3->bitsandbytes) (2.1.5)

# %% [markdown]
# # Verification of some installs

# %%
import torch

print("Torch version:", torch.__version__)
if torch.cuda.is_available():
    print("CUDA available:", torch.cuda.is_available())
    print("GPU:", torch.cuda.get_device_name(0))

import bitsandbytes as bnb
print("bitsandbytes version:", bnb.__version__)

print(np.__version__)
print(pd.__version__)
# Out:
# Torch version: 2.10.0+cu128
# CUDA available: True
# GPU: NVIDIA L4
# bitsandbytes version: 0.49.2
# 1.26.4
# 2.2.2

# %% [markdown]
# # Download Our Code

# %%
# %cd /
if os.path.exists("CS491-691-Adaptation-of-NatureLM-to-Unseen-Domains"):
  import shutil
  shutil.rmtree("CS491-691-Adaptation-of-NatureLM-to-Unseen-Domains")
# !git clone https://github.com/CarterAWebb827/CS491-691-Adaptation-of-NatureLM-to-Unseen-Domains.git
# Out:
# /
# Cloning into 'CS491-691-Adaptation-of-NatureLM-to-Unseen-Domains'...
# remote: Enumerating objects: 252, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 252 (delta 16), reused 16 (delta 8), pack-reused 227 (from 1)
# Receiving objects: 100% (252/252), 424.07 KiB | 2.32 MiB/s, done.
# Resolving deltas: 100% (142/142), done.

# %%
# %cd "/CS491-691-Adaptation-of-NatureLM-to-Unseen-Domains"
# !git checkout fasd13-animal-sounds
# !ls -la
# Out:
# /CS491-691-Adaptation-of-NatureLM-to-Unseen-Domains
# Branch 'fasd13-animal-sounds' set up to track remote branch 'fasd13-animal-sounds' from 'origin'.
# Switched to a new branch 'fasd13-animal-sounds'
# total 288
# drwxr-xr-x 5 root root   4096 Mar 29 18:06 .
# drwxr-xr-x 1 root root   4096 Mar 29 18:06 ..
# -rw-r--r-- 1 root root   9406 Mar 29 18:06 anura_dataset.py
# -rw-r--r-- 1 root root  10244 Mar 29 18:06 .DS_Store
# -rw-r--r-- 1 root root   9896 Mar 29 18:06 fasd13_dataset.py
# drwxr-xr-x 4 root root   4096 Mar 29 18:06 flowcharts
# drwxr-xr-x 8 root root   4096 Mar 29 18:06 .git
# -rw-r--r-- 1 root root   4895 Mar 29 18:06 .gitignore
# -rw-r--r-- 1 root root  14721 Mar 29 18:06 noaa_dataset.py
# -rw-r--r-- 1 root root   5287 Mar 29 18:06 noaa_zero_shot.py
# drwxr-xr-x 4 root root   4096 Mar 29 18:06 outputs
# -rw-r--r-- 1 root root     52 Mar 29 18:06 README.md
# -rw-r--r-- 1 root root  12237 Mar 29 18:06 rfcx_dataset.py
# -rw-r--r-- 1 root root  18432 Mar 29 18:06 rfcx_fine_tune.py
# -rw-r--r-- 1 root root  13250 Mar 29 18:06 rfcx_zero_shot.py
# -rw-r--r-- 1 root root 134515 Mar 29 18:06 setup.ipynb
# -rw-r--r-- 1 root root   6559 Mar 29 18:06 xeno_dataset.py
# -rw-r--r-- 1 root root   4883 Mar 29 18:06 xeno_zero_shot.py

# %%
from noaa_dataset import RightWhaleDataset

class NOAAConfig():
    root_dir = "/content/drive/MyDrive/RightWhaleData"
    data_dir = "/content/drive/MyDrive/RightWhaleData"

config = NOAAConfig()

RightWhaleDataset._is_prepared = False
RightWhaleDataset._train_df = None
RightWhaleDataset._valid_df = None
RightWhaleDataset._test_df = None
RightWhaleDataset._label_columns = None

print("config.root_dir:", getattr(config, "root_dir", None))
print("config.data_dir:", getattr(config, "data_dir", None))

from os import path

dataset = RightWhaleDataset(config, root_dir=config.data_dir)
# Out:
# config.root_dir: /content/drive/MyDrive/RightWhaleData
# config.data_dir: /content/drive/MyDrive/RightWhaleData
# ==============================
# Dataset splits created:
# 	Train: 6496 samples
# 	Valid: 1624 samples
# 	Test: 903 samples
# ==============================
# Loaded train split: 6496 samples
# Number of species: 1

# %% [markdown]
# Run the zero-shot

# %%
# !python noaa_zero_shot.py
# Out:
# Loading the dataset...
# ==============================
# Dataset splits created:
# 	Train: 6496 samples
# 	Valid: 1624 samples
# 	Test: 903 samples
# ==============================
# Loaded test split: 903 samples
# Number of species: 1
# NOAA DataFrame shape: (903, 20)
# Columns: ['audio_path', 'clip_start_seconds', 'clip_end_seconds', 'detection_start_time', 'detection_end_time', 'chunk_start_time', 'chunk_end_time', 'task', 'instruction', 'output', 'Right Whale', 'dataset_name', 'source_csv', 'dataset_dir', 'selection', 'species_code', 'detection_confidence', 'channel', 'low_freq_hz', 'high_freq_hz']
# Preparing clip audio...
# Running the pipeline...
# Loading the pipeline...
# config.json: 1.39kB [00:00, 869kB/s]
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_http.py", line 409, in hf_raise_for_status
#     response.raise_for_status()
#   File "/usr/local/lib/python3.12/dist-packages/requests/models.py", line 1026, in raise_for_status
#     raise HTTPError(http_error_msg, response=self)
# requests.exceptions.HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/meta-llama/Meta-Llama-3.1-8B-Instruct/resolve/main/config.json
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/transformers/utils/hub.py", line 402, in cached_file
#     resolved_file = hf_hub_download(
#                     ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 862, in hf_hub_download
#     return _hf_hub_download_to_cache_dir(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 969, in _hf_hub_download_to_cache_dir
#     _raise_on_head_call_error(head_call_error, force_download, local_files_only)
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 1486, in _raise_on_head_call_error
#     raise head_call_error
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 1376, in _get_metadata_or_catch_error
#     metadata = get_hf_file_metadata(
#                ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 1296, in get_hf_file_metadata
#     r = _request_wrapper(
#         ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 280, in _request_wrapper
#     response = _request_wrapper(
#                ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py", line 304, in _request_wrapper
#     hf_raise_for_status(response)
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_http.py", line 426, in hf_raise_for_status
#     raise _format(GatedRepoError, message, response) from e
# huggingface_hub.errors.GatedRepoError: 401 Client Error. (Request ID: Root=1-69c96de6-12a3158b6f9ae549097b81c6;f31bfa1c-8cc5-4ec3-b140-cc0ee9b48263)
#
# Cannot access gated repo for url https://huggingface.co/meta-llama/Meta-Llama-3.1-8B-Instruct/resolve/main/config.json.
# Access to model meta-llama/Llama-3.1-8B-Instruct is restricted. You must have access to it and be authenticated to access it. Please log in.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/CS491-691-Adaptation-of-NatureLM-to-Unseen-Domains/noaa_zero_shot.py", line 165, in <module>
#     main()
#   File "/CS491-691-Adaptation-of-NatureLM-to-Unseen-Domains/noaa_zero_shot.py", line 88, in main
#     infer_pipe = Pipeline(cfg_path=cfg_path)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/NatureLMaudio/NatureLM/infer.py", line 148, in __init__
#     self.model, self.cfg = load_model_and_config(cfg_path)
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/NatureLMaudio/NatureLM/infer.py", line 40, in load_model_and_config
#     model = NatureLM.from_pretrained("EarthSpeciesProject/NatureLM-audio")
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_validators.py", line 114, in _inner_fn
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/hub_mixin.py", line 553, in from_pretrained
#     instance = cls._from_pretrained(
#                ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/huggingface_hub/hub_mixin.py", line 774, in _from_pretrained
#     model = cls(**model_kwargs)
#             ^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/NatureLMaudio/NatureLM/models/NatureLM.py", line 189, in __init__
#     self.llama_tokenizer = AutoTokenizer.from_pretrained(llama_path, use_fast=False)
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/auto/tokenization_auto.py", line 854, in from_pretrained
#     config = AutoConfig.from_pretrained(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/auto/configuration_auto.py", line 976, in from_pretrained
#     config_dict, unused_kwargs = PretrainedConfig.get_config_dict(pretrained_model_name_or_path, **kwargs)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/configuration_utils.py", line 632, in get_config_dict
#     config_dict, kwargs = cls._get_config_dict(pretrained_model_name_or_path, **kwargs)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/configuration_utils.py", line 689, in _get_config_dict
#     resolved_config_file = cached_file(
#                            ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/utils/hub.py", line 420, in cached_file
#     raise EnvironmentError(
# OSError: You are trying to access a gated repo.
# Make sure to have access to it at https://huggingface.co/meta-llama/Meta-Llama-3.1-8B-Instruct.
# 401 Client Error. (Request ID: Root=1-69c96de6-12a3158b6f9ae549097b81c6;f31bfa1c-8cc5-4ec3-b140-cc0ee9b48263)
#
# Cannot access gated repo for url https://huggingface.co/meta-llama/Meta-Llama-3.1-8B-Instruct/resolve/main/config.json.
# Access to model meta-llama/Llama-3.1-8B-Instruct is restricted. You must have access to it and be authenticated to access it. Please log in.
